# %% [markdown]
# <a href="https://colab.research.google.com/github/SBekzod/ai_foundation/blob/main/data_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader
downloader.download(
    "uzbek pilaf plov food",
    limit=100,
    output_dir='/content/pilaf_images',
    adult_filter_off=True,
    force_replace=False,
    timeout=60
)
# Out:
# [%] Downloading Images to /content/pilaf_images/uzbek pilaf plov food
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://thumbs.dreamstime.com/z/uzbek-cuisine-food-pilaf-plov-uzbek-cuisine-food-pilaf-plov-salad-achichuk-achuchuk-made-mutton-rice-carrots-vegetable-oil-205103317.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://thumbs.dreamstime.com/z/uzbek-cuisine-food-pilaf-plov-uzbek-cuisine-food-pilaf-plov-salad-achichuk-achuchuk-made-mutton-rice-carrots-vegetable-oil-205103447.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://thumbs.dreamstime.com/z/uzbek-cuisine-food-pilaf-plov-uzbek-cuisine-food-pilaf-plov-salad-achichuk-achuchuk-made-mutton-rice-carrots-vegetable-oil-205103463.jpg
# [%] File Downloaded !
#
# ...

# %%
# !rm -rf "/content/drive"
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os, shutil

source_dir = '/content/pilaf_images/uzbek pilaf plov food'
target_dir = '/content/drive/MyDrive/food101_dataset/pilaf'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(source_dir):
    src_file = os.path.join(source_dir, filename)
    dst_file = os.path.join(target_dir, filename)
    shutil.move(src_file, dst_file)

# %%
from bing_image_downloader import downloader
downloader.download(
    "uzbek shashlik kebab food",
    limit=100,
    output_dir='/content/kebab_images',
    adult_filter_off=True,
    force_replace=False,
    timeout=60
)
# Out:
# [%] Downloading Images to /content/kebab_images/uzbek shashlik kebab food
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEhuBqBIWh_FukM_yCxyhLQ8TYZGhGN4mwBdwwFCdEkVyGmQJT1TIEu27cdqVxyBObKilumX3ITsGG1xaVxpumqx_0RuPSEf6-cdArft8JuuLzcMTuk1t5Wv-S6YgMUlmPsPhaWXoFuaX_Ap/w1200-h630-p-k-no-nu/ss4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://gopersis.com/wp-content/uploads/Shashlik-Kebab.jpg
# [!] Issue getting: https://gopersis.com/wp-content/uploads/Shashlik-Kebab.jpg
# [!] Error:: <urlopen error timed out>
# [%] Downloading Image #2 from https://www.shutterstock.com/image-photo/cooking-shashlik-traditional-uzbek-meat-260nw-1582607893.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://img.turkishstylecooking.com/wp-content/uploads/2024/12/ozbek_saslik1-768x512.jpg
# [%] File Downloaded !
#
# ...

# %%
import os, shutil

source_dir = '/content/kebab_images/uzbek shashlik kebab food'
target_dir = '/content/drive/MyDrive/food101_dataset/kebab'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(source_dir):
    src_file = os.path.join(source_dir, filename)
    dst_file = os.path.join(target_dir, filename)
    shutil.move(src_file, dst_file)

# %%
# ICRAWLER orqali rasm yig'ish

# !pip install icrawler
# from icrawler.builtin import BingImageCrawler, GoogleImageCrawler

# queries = [
#     "kebab shashlik food",
#     "uzbek shashlik kebab skewers",
#     "grilled meat skewers kebab",
# ]

# for q in queries:
#     crawler = BingImageCrawler(storage={'root_dir': "/content/kebab_images/icrawler"})
#     crawler.crawl(keyword=q, max_num=60, filters={"type": "photo"})
